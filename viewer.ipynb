# %%
import nibabel as nib
import matplotlib.pyplot as plt
import seaborn as sns

# %%
nifti_img = nib.load('../VALDO_Dataset/Task2/sub-101/sub-101_space-T2S_CMB.nii.gz')

# %% [raw]
# nifti_img = nib.load('Task2\sub-101\sub-101_space-T2S_desc-masked_T2S.nii.gz')

# %%
data = nifti_img.get_fdata()

slice = data[:, :, 16]

sns.heatmap(slice)
# Out:
# <Axes: >

# %%
nifti_img = nib.load('Task2\sub-101\sub-101_space-T2S_desc-masked_T2S.nii.gz')

data = nifti_img.get_fdata()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File c:\Users\nigel\AppData\Local\Programs\Python\Python310\lib\site-packages\nibabel\loadsave.py:100, in load(filename, **kwargs)
#      99 try:
# --> 100     stat_result = os.stat(filename)
#     101 except OSError:
#
# FileNotFoundError: [WinError 3] The system cannot find the path specified: 'Task2/sub-101/sub-101_space-T2S_desc-masked_T2S.nii.gz'
#
# During handling of the above exception, another exception occurred:
#
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 nifti_img = nib.load('Task2\sub-101\sub-101_space-T2S_desc-masked_T2S.nii.gz')
#       3 data = nifti_img.get_fdata()
#
# File c:\Users\nigel\AppData\Local\Programs\Python\Python310\lib\site-packages\nibabel\loadsave.py:102, in load(filename, **kwargs)
#     100     stat_result = os.stat(filename)
# ...

# %%
fig, axes = plt.subplots(10, 5, figsize=(30, 40))

fig.tight_layout()

for ax, i in zip(axes.flat, range(30)):
    slice = data[:, :, i]
    sns.heatmap(slice, ax=ax, cmap='gray')
